# %%
import numpy as np
from array import array

# %%
matriz = np.array([[1.0,2],[3,4]])
matriz
# Out:
# array([[1., 2.],
#        [3., 4.]])

# %%
tensor = np.array([[[1,2],[3,4]],[[5,6],[7,8]]])
tensor
# Out:
# array([[[1, 2],
#         [3, 4]],
#
#        [[5, 6],
#         [7, 8]]])

# %%
print(matriz.dtype)
print(tensor.dtype)
# Out:
# float64
# int32

# %%
matriz = np.array([[[1, 5, 3],[4, 5, 6]], [[1, 5, 3],[4, 5, 6]]])
print(matriz)
matriz.shape
# Out:
# [[[1 5 3]
#   [4 5 6]]
#
#  [[1 5 3]
#   [4 5 6]]]
# (2, 2, 3)

# %%
pip install pandas
# Out:
# ^C
# Note: you may need to restart the kernel to use updated packages.
# ...
#   Obtaining dependency information for pandas from https://files.pythonhosted.org/packages/ae/d9/3741b344f57484b423cd22194025a8489992ad9962196a62721ef9980045/pandas-2.1.4-cp312-cp312-win_amd64.whl.metadata
# ...
#   Obtaining dependency information for pytz>=2020.1 from https://files.pythonhosted.org/packages/32/4d/aaf7eff5deb402fd9a24a1449a8119f00d74ae9c2efa79f8ef9994261fc2/pytz-2023.3.post1-py2.py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for tzdata>=2022.1 from https://files.pythonhosted.org/packages/a3/fb/52b62131e21b24ee297e4e95ed41eba29647dad0e0051a92bb66b43c70ff/tzdata-2023.4-py2.py3-none-any.whl.metadata
# ...
#    ---------------------------------------- 0.0/10.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/10.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/10.5 MB 388.9 kB/s eta 0:00:27
# ...

# %%
import pandas as pd

# %%
arr_2 = np.full((5,2), 10)
arr_2
# Out:
# array([[10, 10],
#        [10, 10],
#        [10, 10],
#        [10, 10],
#        [10, 10]])

# %%
arr_3 = np.random.rand(4,2)
arr_3
# Out:
# array([[0.43914043, 0.51959275],
#        [0.27000758, 0.91399848],
#        [0.82656641, 0.20282935],
#        [0.14852542, 0.39275465]])

# %%
arr_4 = np.random.randint(5, 20, size = (3, 3))
arr_4
# Out:
# array([[ 7, 18,  5],
#        [ 8, 13,  5],
#        [13, 14, 14]])

# %%
arr_4[1,1]
# Out:
# 13

# %%
arr_4[0:2, 0:2]
# Out:
# array([[ 7, 18],
#        [ 8, 13]])

# %%
arr_4[0:2, :]
# Out:
# array([[ 7, 18,  5],
#        [ 8, 13,  5]])

# %%
arr = np.random.randint(5, 20, size = (3, 3))
arr
# Out:
# array([[17, 16, 18],
#        [ 9,  5, 13],
#        [18,  8,  9]])

# %%
arr.sum()
# Out:
# 113

# %%
arr_5 = np.array(range(10,20))

# %%
pd.Series(arr_5)
# Out:
# 0    10
# 1    11
# 2    12
# 3    13
# 4    14
# 5    15
# 6    16
# 7    17
# 8    18
# 9    19
# dtype: int32

# %%
from datetime import datetime

# %%
df = pd.DataFrame(arr, columns=['a', 'b', 'c'])
df ['idade'] = [10, 20, 30]
df
# Out:
#     a   b   c  idade
# 0  17  16  18     10
# 1   9   5  13     20
# 2  18   8   9     30

# %%
df1 = pd.DataFrame({'Nome': ['João', 'Maria'], 'Idade': [20, 50]})
df1
# Out:
#     Nome  Idade
# 0   João     20
# 1  Maria     50

# %% [markdown]
# Exercícios

# %%
np.array([10, 20, 30, 40, 50, 60, 70, 80, 100])
# Out:
# array([ 10,  20,  30,  40,  50,  60,  70,  80, 100])

# %%
matriz2 = np.array([[0,3], [0,4], [5,0], [1,0], [8,1]])
matriz2
# Out:
# array([[0, 3],
#        [0, 4],
#        [5, 0],
#        [1, 0],
#        [8, 1]])

# %%
matriz2.min
# Out:
# <function ndarray.min>
