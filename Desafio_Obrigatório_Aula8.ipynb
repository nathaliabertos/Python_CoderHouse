# %%
import pandas as pd

# %%
pip install openpyxl
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 23.3.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
df = pd.read_excel('best-selling game consoles.xlsx',
                   sheet_name='consoles')
df.tail()
# Out:
#     Console Name       Type  Company  Released Year  Discontinuation Year  \
# 46    Atari 7800       Home    Atari           1986                  1991
# 47    Atari Lynx   Handheld    Atari           1989                  1995
# 48  Philips CD-i       Home  Philips           1990                  1998
# 49       Telstar  Dedicated   Coleco           1976                  1978
# 50    Atari 5200       Home    Atari           1982                  1984
#
#     Units sold (million)                                 Remarks
# 46                   1.0  Final sales are greater than 1 million
# 47                   1.0  Final sales are greater than 1 million
# 48                   1.0  Final sales are greater than 1 million
# 49                   1.0  Final sales are greater than 1 million
# 50                   1.0  Final sales are greater than 1 million

# %%
df.to_excel('bestselling.xlsx')

# %%
games = pd.read_excel('bestselling.xlsx')
games.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Unnamed: 0            51 non-null     int64
#  1   Console Name          51 non-null     object
#  2   Type                  51 non-null     object
#  3   Company               51 non-null     object
#  4   Released Year         51 non-null     int64
#  5   Discontinuation Year  51 non-null     int64
#  6   Units sold (million)  51 non-null     float64
#  7   Remarks               16 non-null     object
# dtypes: float64(1), int64(3), object(4)
# memory usage: 3.3+ KB

# %%
games.describe()
# Out:
#        Unnamed: 0  Released Year  Discontinuation Year  Units sold (million)
# count   51.000000      51.000000             51.000000             51.000000
# mean    25.000000    1996.058824           1844.803922             35.549412
# std     14.866069      12.378064            543.657319             42.608844
# min      0.000000    1976.000000              0.000000              1.000000
# 25%     12.500000    1987.500000           1992.000000              3.200000
# 50%     25.000000    1994.000000           1998.000000             13.560000
# 75%     37.500000    2004.500000           2011.500000             60.205000
# max     50.000000    2020.000000           2020.000000            155.000000

# %%
games['Console Name'].str.replace('NES', 'Nitendinho')
games['Console Name'].str.upper()
# Out:
# 0                         PLAYSTATION 2
# 1                           NINTENDO DS
# 2                       NINTENDO SWITCH
# 3                              GAME BOY
# 4                        GAME BOY COLOR
# 5                         PLAYSTATION 4
# 6                           PLAYSTATION
# 7                                   WII
# 8                         PLAYSTATION 3
# 9                              XBOX 360
# 10                     GAME BOY ADVANCE
# 11                 PLAYSTATION PORTABLE
# 12                         NINTENDO 3DS
# 13                          NES/FAMICOM
# 14                             XBOX ONE
# 15                   SNES/SUPER FAMICOM
# 16                         GAME & WATCH
# 17                          NINTENDO 64
# 18              SEGA GENESIS/MEGA DRIVE
# 19                        PLAYSTATION 5
# 20                           ATARI 2600
# 21                                 XBOX
# 22                             GAMECUBE
# ...

# %%
df[df['Released Year']>2010]
# Out:
#                  Console Name       Type    Company  Released Year  \
# 2             Nintendo Switch     Hybrid   Nintendo           2017
# 5               PlayStation 4       Home       Sony           2013
# 12               Nintendo 3DS   Handheld   Nintendo           2011
# 14                   Xbox One       Home  Microsoft           2013
# 19              PlayStation 5       Home       Sony           2020
# 23            Xbox Series X/S       Home  Microsoft           2020
# 24                      Wii U       Home   Nintendo           2012
# 25           PlayStation Vita   Handheld       Sony           2011
# 33  Super NES Classic Edition  Dedicated   Nintendo           2017
# 35        NES Classic Edition  Dedicated   Nintendo           2016
#
#     Discontinuation Year  Units sold (million)  \
# 2                      0                122.55
# 5                      0                117.20
# 12                  2020                 75.94
# ...

# %%
games.describe()
# Out:
#        Unnamed: 0  Released Year  Discontinuation Year  Units sold (million)
# count   51.000000      51.000000             51.000000             51.000000
# mean    25.000000    1996.058824           1844.803922             35.549412
# std     14.866069      12.378064            543.657319             42.608844
# min      0.000000    1976.000000              0.000000              1.000000
# 25%     12.500000    1987.500000           1992.000000              3.200000
# 50%     25.000000    1994.000000           1998.000000             13.560000
# 75%     37.500000    2004.500000           2011.500000             60.205000
# max     50.000000    2020.000000           2020.000000            155.000000

# %%
games.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Unnamed: 0            51 non-null     int64
#  1   Console Name          51 non-null     object
#  2   Type                  51 non-null     object
#  3   Company               51 non-null     object
#  4   Released Year         51 non-null     int64
#  5   Discontinuation Year  51 non-null     int64
#  6   Units sold (million)  51 non-null     float64
#  7   Remarks               16 non-null     object
# dtypes: float64(1), int64(3), object(4)
# memory usage: 3.3+ KB

# %%
df.isnull()
# Out:
#     Console Name   Type  Company  Released Year  Discontinuation Year  \
# 0          False  False    False          False                 False
# 1          False  False    False          False                 False
# 2          False  False    False          False                 False
# 3          False  False    False          False                 False
# 4          False  False    False          False                 False
# 5          False  False    False          False                 False
# 6          False  False    False          False                 False
# 7          False  False    False          False                 False
# 8          False  False    False          False                 False
# 9          False  False    False          False                 False
# 10         False  False    False          False                 False
# 11         False  False    False          False                 False
# ...

# %%
df.fillna('missing', inplace=True)
df.isnull()
# Out:
#     Console Name   Type  Company  Released Year  Discontinuation Year  \
# 0          False  False    False          False                 False
# 1          False  False    False          False                 False
# 2          False  False    False          False                 False
# 3          False  False    False          False                 False
# 4          False  False    False          False                 False
# 5          False  False    False          False                 False
# 6          False  False    False          False                 False
# 7          False  False    False          False                 False
# 8          False  False    False          False                 False
# 9          False  False    False          False                 False
# 10         False  False    False          False                 False
# 11         False  False    False          False                 False
# ...

# %%
df.tail()
# Out:
#     Console Name       Type  Company  Released Year  Discontinuation Year  \
# 46    Atari 7800       Home    Atari           1986                  1991
# 47    Atari Lynx   Handheld    Atari           1989                  1995
# 48  Philips CD-i       Home  Philips           1990                  1998
# 49       Telstar  Dedicated   Coleco           1976                  1978
# 50    Atari 5200       Home    Atari           1982                  1984
#
#     Units sold (million)                                 Remarks
# 46                   1.0  Final sales are greater than 1 million
# 47                   1.0  Final sales are greater than 1 million
# 48                   1.0  Final sales are greater than 1 million
# 49                   1.0  Final sales are greater than 1 million
# 50                   1.0  Final sales are greater than 1 million

# %%
games['descontinuado'] = games['Discontinuation Year'] - games['Released Year']

# %%
games.loc[(games['descontinuado']<=2)&(games['descontinuado']>0),
             ['Console Name','Released Year','Discontinuation Year']]
# Out:
#                  Console Name  Released Year  Discontinuation Year
# 33  Super NES Classic Edition           2017                  2018
# 35        NES Classic Edition           2016                  2018
# 41                     N-Gage           2003                  2005
# 49                    Telstar           1976                  1978
# 50                 Atari 5200           1982                  1984
