# %%
import pandas as pd

# %%
import numpy as np

# %%
df = pd.read_csv('realtor-data.csv')

# %%
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 99995     True
# 99996     True
# 99997     True
# 99998     True
# 99999     True
# Length: 100000, dtype: bool

# %%
df[df.duplicated()==True]
# Out:
#          status  bed  bath  acre_lot        city          state  zip_code  \
# 77     for_sale  NaN   NaN      0.21      Aguada    Puerto Rico     602.0
# 135    for_sale  3.0   2.0      0.08       Ponce    Puerto Rico     728.0
# 139    for_sale  5.0   3.0      7.46  Las Marias    Puerto Rico     670.0
# 140    for_sale  3.0   2.0      0.10       Lares    Puerto Rico     669.0
# 148    for_sale  3.0   2.0      0.05       Yauco    Puerto Rico     698.0
# ...         ...  ...   ...       ...         ...            ...       ...
# 99995  for_sale  3.0   3.0       NaN      Hudson  Massachusetts    1749.0
# 99996  for_sale  2.0   1.0      0.34      Auburn  Massachusetts    1501.0
# 99997  for_sale  3.0   2.0      1.01  Shrewsbury  Massachusetts    1545.0
# 99998  for_sale  3.0   2.0      0.12   Worcester  Massachusetts    1604.0
# 99999  for_sale  3.0   3.0     21.67     Grafton  Massachusetts    1536.0
#
#        house_size prev_sold_date     price
# ...

# %%
df = df.drop_duplicates()
df
# Out:
#          status  bed  bath  acre_lot        city          state  zip_code  \
# 0      for_sale  3.0   2.0      0.12    Adjuntas    Puerto Rico     601.0
# 1      for_sale  4.0   2.0      0.08    Adjuntas    Puerto Rico     601.0
# 2      for_sale  2.0   1.0      0.15  Juana Diaz    Puerto Rico     795.0
# 3      for_sale  4.0   2.0      0.10       Ponce    Puerto Rico     731.0
# 4      for_sale  6.0   2.0      0.05    Mayaguez    Puerto Rico     680.0
# ...         ...  ...   ...       ...         ...            ...       ...
# 96947  for_sale  3.0   2.0      0.90     Bristol   Rhode Island    2809.0
# 96952  for_sale  4.0   3.0      0.24  Barrington   Rhode Island    2806.0
# 96953  for_sale  2.0   2.0       NaN      Natick  Massachusetts    1760.0
# 97265  for_sale  3.0   2.0      0.36  Framingham  Massachusetts    1701.0
# 97288  for_sale  3.0   1.0      0.09  Framingham  Massachusetts    1702.0
#
#        house_size prev_sold_date     price
# ...

# %%
df = df.drop_duplicates(subset= ['city', 'zip_code'])
df.head()
# Out:
#      status  bed  bath  acre_lot           city        state  zip_code  \
# 0  for_sale  3.0   2.0      0.12       Adjuntas  Puerto Rico     601.0
# 2  for_sale  2.0   1.0      0.15     Juana Diaz  Puerto Rico     795.0
# 3  for_sale  4.0   2.0      0.10          Ponce  Puerto Rico     731.0
# 4  for_sale  6.0   2.0      0.05       Mayaguez  Puerto Rico     680.0
# 5  for_sale  4.0   3.0      0.46  San Sebastian  Puerto Rico     612.0
#
#    house_size prev_sold_date     price
# 0       920.0            NaN  105000.0
# 2       748.0            NaN   67000.0
# 3      1800.0            NaN  145000.0
# 4         NaN            NaN   65000.0
# 5      2520.0            NaN  179000.0

# %%
l1 = [f'2020-01-{i}' for i in range (1, 20)]
l1
# Out:
# ['2020-01-1',
#  '2020-01-2',
#  '2020-01-3',
#  '2020-01-4',
#  '2020-01-5',
#  '2020-01-6',
#  '2020-01-7',
#  '2020-01-8',
#  '2020-01-9',
#  '2020-01-10',
#  '2020-01-11',
#  '2020-01-12',
#  '2020-01-13',
#  '2020-01-14',
#  '2020-01-15',
#  '2020-01-16',
#  '2020-01-17',
#  '2020-01-18',
#  '2020-01-19']

# %%
l2 = [f'2024-02-08' for i in range (1, 20)]
dates = pd.DataFrame({'inicio': l1, 'fim':l2})
dates.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19 entries, 0 to 18
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   inicio  19 non-null     object
#  1   fim     19 non-null     object
# dtypes: object(2)
# memory usage: 436.0+ bytes

# %%
dates['inicio']=pd.to_datetime(dates['inicio'], format= '%Y-%m-%d')
dates['fim']=pd.to_datetime(dates['fim'], format= '%Y-%m-%d')
dates.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19 entries, 0 to 18
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   inicio  19 non-null     datetime64[ns]
#  1   fim     19 non-null     datetime64[ns]
# dtypes: datetime64[ns](2)
# memory usage: 436.0 bytes

# %%
dates
# Out:
#        inicio        fim
# 0  2020-01-01 2024-02-08
# 1  2020-01-02 2024-02-08
# 2  2020-01-03 2024-02-08
# 3  2020-01-04 2024-02-08
# 4  2020-01-05 2024-02-08
# 5  2020-01-06 2024-02-08
# 6  2020-01-07 2024-02-08
# 7  2020-01-08 2024-02-08
# 8  2020-01-09 2024-02-08
# 9  2020-01-10 2024-02-08
# 10 2020-01-11 2024-02-08
# 11 2020-01-12 2024-02-08
# 12 2020-01-13 2024-02-08
# 13 2020-01-14 2024-02-08
# 14 2020-01-15 2024-02-08
# 15 2020-01-16 2024-02-08
# 16 2020-01-17 2024-02-08
# 17 2020-01-18 2024-02-08
# 18 2020-01-19 2024-02-08

# %%
dates['dif'] = (dates['fim'] - dates['inicio'])

# %%
df.head()
# Out:
#      status  bed  bath  acre_lot           city        state  zip_code  \
# 0  for_sale  3.0   2.0      0.12       Adjuntas  Puerto Rico     601.0
# 2  for_sale  2.0   1.0      0.15     Juana Diaz  Puerto Rico     795.0
# 3  for_sale  4.0   2.0      0.10          Ponce  Puerto Rico     731.0
# 4  for_sale  6.0   2.0      0.05       Mayaguez  Puerto Rico     680.0
# 5  for_sale  4.0   3.0      0.46  San Sebastian  Puerto Rico     612.0
#
#    house_size prev_sold_date     price
# 0       920.0            NaN  105000.0
# 2       748.0            NaN   67000.0
# 3      1800.0            NaN  145000.0
# 4         NaN            NaN   65000.0
# 5      2520.0            NaN  179000.0

# %%
df.sort_values('price')
# Out:
#          status   bed  bath  acre_lot         city           state  zip_code  \
# 77063  for_sale   NaN   NaN      0.98        Weare   New Hampshire    3281.0
# 68159  for_sale   NaN   NaN      2.50      Jaffrey   New Hampshire    3458.0
# 41911  for_sale   NaN   NaN      1.20     Stamford         Vermont    5350.0
# 33769  for_sale   NaN   NaN     17.30  Bernardston   Massachusetts    1337.0
# 34828  for_sale   NaN   NaN       NaN    McCormick  South Carolina   29835.0
# ...         ...   ...   ...       ...          ...             ...       ...
# 64681  for_sale   6.0   8.0     66.00      Wassaic        New York   12522.0
# 62484  for_sale   4.0   5.0    172.71       Amenia        New York   12592.0
# 124    for_sale   NaN   NaN    247.57      Isabela     Puerto Rico     603.0
# 64337  for_sale   4.0   6.0     55.40        Milan        New York   12571.0
# 56664  for_sale  10.0  15.0    450.95     Cornwall     Connecticut    6753.0
#
#        house_size prev_sold_date       price
# ...

# %%
df.sort_values(['price', 'city'], ascending=False)
# Out:
#          status   bed  bath  acre_lot         city           state  zip_code  \
# 56664  for_sale  10.0  15.0    450.95     Cornwall     Connecticut    6753.0
# 64337  for_sale   4.0   6.0     55.40        Milan        New York   12571.0
# 124    for_sale   NaN   NaN    247.57      Isabela     Puerto Rico     603.0
# 62484  for_sale   4.0   5.0    172.71       Amenia        New York   12592.0
# 64681  for_sale   6.0   8.0     66.00      Wassaic        New York   12522.0
# ...         ...   ...   ...       ...          ...             ...       ...
# 34828  for_sale   NaN   NaN       NaN    McCormick  South Carolina   29835.0
# 33769  for_sale   NaN   NaN     17.30  Bernardston   Massachusetts    1337.0
# 41911  for_sale   NaN   NaN      1.20     Stamford         Vermont    5350.0
# 68159  for_sale   NaN   NaN      2.50      Jaffrey   New Hampshire    3458.0
# 77063  for_sale   NaN   NaN      0.98        Weare   New Hampshire    3281.0
#
#        house_size prev_sold_date       price
# ...

# %%
df.groupby(['state', 'city'])[['price']].mean()
# Out:
#                                  price
# state          city
# Connecticut    Andover         52000.0
#                Ashford        100000.0
#                Avon           169900.0
#                Barkhamsted     57000.0
#                Berlin         595000.0
# ...                                ...
# Virgin Islands Frederiksted   199000.0
#                Kingshill      225000.0
#                Saint John    4850000.0
#                Saint Thomas   175000.0
# Virginia       Chincoteague    75000.0
#
# [582 rows x 1 columns]
