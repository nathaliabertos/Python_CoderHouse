# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.DataFrame({'X':[14,33,42,54,62,71],
                   'Y':[1,3,4,5,6,4]})
df
# Out:
#     X  Y
# 0  14  1
# 1  33  3
# 2  42  4
# 3  54  5
# 4  62  6
# 5  71  4

# %%
pip install sklearn

# %%
pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in c:\users\natha\appdata\local\programs\python\python312\lib\site-packages (1.4.1.post1)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: numpy<2.0,>=1.19.5 in c:\users\natha\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn) (1.26.3)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\natha\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn) (1.12.0)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\natha\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\natha\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn) (3.3.0)
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from sklearn.linear_model import LinearRegression

# %%
modelo = LinearRegression()
modelo.fit(df[['X']], df[['Y']])
# Out:
# LinearRegression()

# %%
modelo = LinearRegression()
modelo.fit(df[['X']], df[['Y']])
modelo.predict(df[['X']])
# Out:
# array([[1.61977716],
#        [2.93407614],
#        [3.55663881],
#        [4.38672238],
#        [4.94011142],
#        [5.56267409]])

# %%
modelo = LinearRegression()
modelo.fit(df[['X']], df[['Y']])
df['YPred']=modelo.predict(df[['X']])
df
# Out:
#     X  Y     YPred
# 0  14  1  1.619777
# 1  33  3  2.934076
# 2  42  4  3.556639
# 3  54  5  4.386722
# 4  62  6  4.940111
# 5  71  4  5.562674

# %%
plt.scatter(df['X'], df['Y'])
plt.plot(df['X'], df['YPred'], color= 'red')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
from sklearn.metrics import r2_score
r2 = r2_score(df['Y'], df['YPred'])
r2
# Out:
# 0.6948452317611342
